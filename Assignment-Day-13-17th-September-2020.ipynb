# %% [markdown]
# ### 1. Import different required library

# %%
import pandas as pd
import numpy as np
data = pd.read_csv(r'C:\Users\wwwra\Desktop\LetsUpgrade\creditcard.csv')

# %% [markdown]
# ### 2. Check the version of the Library

# %%
print("Panda Version = " ,pd.__version__)
print("Numpy Version = " ,np.__version__)
# Out:
# Panda Version =  1.0.5
# Numpy Version =  1.18.5

# %% [markdown]
# ### 3. Go for different observation like Info, description

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [markdown]
# ### 4. Check null Values

# %%
col_with_null = [col for col in data.columns if data[col].isnull().any() or data[col].isna().any()]

# %%
col_with_null  # there is no null value in data set
# Out:
# []

# %% [markdown]
# ### 5. Check duplicate values

# %%
duplicates = data[data.duplicated()]
duplicates
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1081 entries, 33 to 284193
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    1081 non-null   float64
#  1   V1      1081 non-null   float64
#  2   V2      1081 non-null   float64
#  3   V3      1081 non-null   float64
#  4   V4      1081 non-null   float64
#  5   V5      1081 non-null   float64
#  6   V6      1081 non-null   float64
#  7   V7      1081 non-null   float64
#  8   V8      1081 non-null   float64
#  9   V9      1081 non-null   float64
#  10  V10     1081 non-null   float64
#  11  V11     1081 non-null   float64
#  12  V12     1081 non-null   float64
#  13  V13     1081 non-null   float64
#  14  V14     1081 non-null   float64
#  15  V15     1081 non-null   float64
#  16  V16     1081 non-null   float64
#  17  V17     1081 non-null   float64
#  18  V18     1081 non-null   float64
#  19  V19     1081 non-null   float64
# ...

# %% [markdown]
# ### 6. Filter for different condition - come up with insights from the dataset, basic plot, distribution plots

# %%
data1 = data.drop_duplicates()

# %%
data1.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
data1.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
data1.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 283726 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    283726 non-null  float64
#  1   V1      283726 non-null  float64
#  2   V2      283726 non-null  float64
#  3   V3      283726 non-null  float64
#  4   V4      283726 non-null  float64
#  5   V5      283726 non-null  float64
#  6   V6      283726 non-null  float64
#  7   V7      283726 non-null  float64
#  8   V8      283726 non-null  float64
#  9   V9      283726 non-null  float64
#  10  V10     283726 non-null  float64
#  11  V11     283726 non-null  float64
#  12  V12     283726 non-null  float64
#  13  V13     283726 non-null  float64
#  14  V14     283726 non-null  float64
#  15  V15     283726 non-null  float64
#  16  V16     283726 non-null  float64
#  17  V17     283726 non-null  float64
#  18  V18     283726 non-null  float64
#  19  V19     283726 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
plt.plot(data1['Time'].head(500),data1['V1'].head(500),'r',data1['V2'].head(500),'b',data1['V3'].head(500))

# %%
plt.figure(figsize=(20,10))
plt.scatter(data1['Time'],data1['V1'])

# %%
data1['V1'].describe()
# Out:
# count    283726.000000
# mean          0.005917
# std           1.948026
# min         -56.407510
# 25%          -0.915951
# 50%           0.020384
# 75%           1.316068
# max           2.454930
# Name: V1, dtype: float64

# %%
data1['V1'].mode(),data1['V1'].median()
# Out:
# (0    1.245674
#  1    2.055797
#  dtype: float64,
#  0.0203840546733839)

# %%
plt.figure(figsize=(10,10))
plt.boxplot(data1['V1'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29a640d1df0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29a640e04f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29a640d1a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x29a640e0bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29a640e0eb0>],
#  'means': []}

# %%
plt.figure(figsize=(10,10))
plt.bar(data1['Time'].head(50),data1['V1'].head(50))
# Out:
# <BarContainer object of 50 artists>

# %% [markdown]
# ### 7. Use a histogram to plot different columns

# %%
plt.hist(data1['V1'])
# Out:
# (array([1.00000e+00, 1.00000e+00, 3.00000e+00, 1.80000e+01, 3.00000e+01,
#         7.80000e+01, 1.80000e+02, 8.62000e+02, 9.29100e+03, 2.73262e+05]),
#  array([-56.40750963, -50.52126567, -44.63502171, -38.74877774,
#         -32.86253378, -26.97628982, -21.09004586, -15.2038019 ,
#          -9.31755793,  -3.43131397,   2.45492999]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data1['Amount'])
# Out:
# (array([2.83314e+05, 3.60000e+02, 3.60000e+01, 1.00000e+01, 2.00000e+00,
#         1.00000e+00, 0.00000e+00, 2.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([    0.   ,  2569.116,  5138.232,  7707.348, 10276.464, 12845.58 ,
#         15414.696, 17983.812, 20552.928, 23122.044, 25691.16 ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(10,10))
plt.scatter(data1['Time'].head(500),data1['Amount'].head(500))

# %%
import inspect
data['Class'].value_counts(normalize=True)
# Out:
# '0'    0.998273
# '1'    0.001727
# Name: Class, dtype: float64

# %%
inspect.getfullargspec(pd.value_counts)
# Out:
# FullArgSpec(args=['values', 'sort', 'ascending', 'normalize', 'bins', 'dropna'], varargs=None, varkw=None, defaults=(True, False, False, None, True), kwonlyargs=[], kwonlydefaults=None, annotations={'return': 'Series', 'sort': <class 'bool'>, 'ascending': <class 'bool'>, 'normalize': <class 'bool'>, 'dropna': <class 'bool'>})

# %%
inspect.getfullargspec(plt.plot)
# Out:
# FullArgSpec(args=[], varargs='args', varkw='kwargs', defaults=None, kwonlyargs=['scalex', 'scaley', 'data'], kwonlydefaults={'scalex': True, 'scaley': True, 'data': None}, annotations={})

# %%
inspect.getfullargspec(plt.figure)
# Out:
# FullArgSpec(args=['num', 'figsize', 'dpi', 'facecolor', 'edgecolor', 'frameon', 'FigureClass', 'clear'], varargs=None, varkw='kwargs', defaults=(None, None, None, None, None, True, <class 'matplotlib.figure.Figure'>, False), kwonlyargs=[], kwonlydefaults=None, annotations={})
